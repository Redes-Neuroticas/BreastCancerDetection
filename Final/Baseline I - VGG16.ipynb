# %%
# Importação das bibliotecas utilizadas no trabalho.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import seaborn as sns
import shutil
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

# %%
# Montando o acesso ao Google Drive na máquina do Colab.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copiando os arquivos do meu Google Drive para a máquina do Colab.
! cp drive/MyDrive/inf0619_trabalho_final/baseline.zip .

# %%
# Extraindo os conjuntos de imagens que estão compactados.
! unzip baseline.zip

# %%
# Alterando a nomenclatura dos diretórios.
! mv baseline/train/wout_cancer baseline/train/0
! mv baseline/train/with_cancer baseline/train/1
! mv baseline/val/wout_cancer baseline/val/0
! mv baseline/val/with_cancer baseline/val/1
! mv baseline/test/wout_cancer baseline/test/0
! mv baseline/test/with_cancer baseline/test/1

# %% [markdown]
# ## Dataset attributes
#
# - **site_id** - ID code for the source hospital.
# - **patient_id** - ID code for the patient.
# - **image_id** - ID code for the image.
# - **laterality** - Whether the image is of the left (L) or right (R) breast.
# - **view** - The orientation of the image. The default for a screening exam is to capture two views per breast.
# - **age** - The patient's age in years.
# - **cancer** - Whether or not the breast was positive for malignant cancer. The target value. Only provided for train.
# - **biopsy** - Whether or not a follow-up biopsy was performed on the breast. Only provided for train.
# - **invasive** - If the breast is positive for cancer, whether or not the cancer proved to be invasive. Only provided for train.
# - **BIRADS** - 0 if the breast required follow-up, 1 if the breast was rated as negative for cancer, and 2 if the breast was rated as normal. Only provided for train.
# - **implant** - Whether or not the patient had breast implants. Site 1 only provides breast implant information at the patient level, not at the breast level.
# - **density** - A rating for how dense the breast tissue is, with A being the least dense and D being the most dense. Extremely dense tissue can make diagnosis more difficult. Only provided for train.
# - **machine_id** - An ID code for the imaging device.
# - **difficult_negative_case** - True if the case was unusually difficult. Only provided for train.

# %% [markdown]
# ## Após separar os grupos de treinamento e validação, ler o parquet e continuar desse ponto.

# %%
# Leitura dos arquivos em parquet que contém a separação do dataset em treinamento e validação na proporção de 80% e 20% respectivamente.
df_train_split = pd.read_parquet("/content/drive/My Drive/inf0619_trabalho_final/df_train_split.parquet")
df_val_split = pd.read_parquet("/content/drive/My Drive/inf0619_trabalho_final/df_val_split.parquet")
df_train_split
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 32231        2       53681   645459855          R  MLO  72.0       0       0
# 5756         1       17691   204137417          L  MLO  54.0       0       0
# 22346        2       39923   939662454          R  MLO  67.0       0       0
# 26661        2       45967   577166135          L  MLO  60.0       0       0
# 2693         1       13556  1513389174          R   CC  64.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 10397        1       24032   292181380          R   CC  74.0       0       0
# 43138        2        9114  1516672792          R  MLO  62.0       0       0
# 23187        1       41047  1845566551          L  MLO  59.0       0       0
# 25449        1       44250  1403117425          R  MLO  76.0       0       0
# 12092        1       26273   970576175          R   CC  64.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 32231         0     NaN        0    None          21                    False
# 5756          0     NaN        0       A          49                    False
# 22346         0     NaN        0    None          48                    False
# 26661         0     NaN        0    None          48                    False
# 2693          0     1.0        0       A          49                    False
# ...         ...     ...      ...     ...         ...                      ...
# 10397         0     1.0        0       B          49                    False
# 43138         0     NaN        0    None          29                    False
# 23187         0     NaN        0       C          49                    False
# 25449         0     0.0        0       C          93                     True
# 12092         0     0.0        0       C          49                     True
#
#                                                 img_path
# 32231  /content/drive/My Drive/inf0619_trabalho_final...
# 5756   /content/drive/My Drive/inf0619_trabalho_final...
# 22346  /content/drive/My Drive/inf0619_trabalho_final...
# 26661  /content/drive/My Drive/inf0619_trabalho_final...
# 2693   /content/drive/My Drive/inf0619_trabalho_final...
# ...                                                  ...
# 10397  /content/drive/My Drive/inf0619_trabalho_final...
# 43138  /content/drive/My Drive/inf0619_trabalho_final...
# 23187  /content/drive/My Drive/inf0619_trabalho_final...
# 25449  /content/drive/My Drive/inf0619_trabalho_final...
# 12092  /content/drive/My Drive/inf0619_trabalho_final...
#
# [34995 rows x 15 columns]

# %%
# Leitura do arquivo .csv que contém as informações dos conjuntos de dados de teste.
df_test = pd.read_csv('/content/drive/My Drive/inf0619_trabalho_final/test.csv', sep=",")
df_test["img_path"] =  "/content/drive/My Drive/inf0619_trabalho_final/images_256_512/" + df_test["patient_id"].astype(str) + "/" + df_test["image_id"].astype(str) + ".png"
df_test
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10048   964141995          L  MLO  62.0       0       0
# 1            2       10048  1234933874          L   CC  62.0       0       0
# 2            2       10048  1577142909          R  MLO  62.0       0       0
# 3            2       10048  1842203124          R   CC  62.0       0       0
# 4            2       10050   588678397          L  MLO  67.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 10957        2        9965  1990076391          R  MLO  67.0       0       0
# 10958        2        9968   766198919          L   CC  76.0       0       0
# 10959        2        9968  2098937312          L  MLO  76.0       0       0
# 10960        2        9968   294168046          R  MLO  76.0       0       0
# 10961        2        9968   568005453          R   CC  76.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 0             0     NaN        0     NaN          29                    False
# 1             0     NaN        0     NaN          29                    False
# 2             0     NaN        0     NaN          29                    False
# 3             0     NaN        0     NaN          29                    False
# 4             0     NaN        0     NaN          29                    False
# ...         ...     ...      ...     ...         ...                      ...
# 10957         0     NaN        0     NaN          21                    False
# 10958         0     NaN        0     NaN          48                    False
# 10959         0     NaN        0     NaN          48                    False
# 10960         0     NaN        0     NaN          48                    False
# 10961         0     NaN        0     NaN          48                    False
#
#                                                 img_path
# 0      /content/drive/My Drive/inf0619_trabalho_final...
# 1      /content/drive/My Drive/inf0619_trabalho_final...
# 2      /content/drive/My Drive/inf0619_trabalho_final...
# 3      /content/drive/My Drive/inf0619_trabalho_final...
# 4      /content/drive/My Drive/inf0619_trabalho_final...
# ...                                                  ...
# 10957  /content/drive/My Drive/inf0619_trabalho_final...
# 10958  /content/drive/My Drive/inf0619_trabalho_final...
# 10959  /content/drive/My Drive/inf0619_trabalho_final...
# 10960  /content/drive/My Drive/inf0619_trabalho_final...
# 10961  /content/drive/My Drive/inf0619_trabalho_final...
#
# [10962 rows x 15 columns]

# %%
# Vamos calcular a distribuição das classes usando a biblioteca scikit-learn:
class_weights = class_weight.compute_class_weight(class_weight = 'balanced'
                                                  , classes = df_train_split["cancer"].unique()
                                                  , y = df_train_split["cancer"])
class_weights
# Out:
# array([ 0.5112939 , 22.63583441])

# %%
# Transformando em um dicionário:
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 0.5112939045058734, 1: 22.635834411384216}

# %%
# Identificação dos caminhos para os conjuntos de dados de treinamento, validação e teste.

dir_path_train = "/content/baseline/train"
dir_path_val = "/content/baseline/val"
dir_path_test = "/content/baseline/test"

# %%
# Criando geradores de imagem para o tensorflow:
train_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.vgg16.preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.vgg16.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.vgg16.preprocess_input)

# %%
train_generator = train_datagen.flow_from_directory(
    dir_path_train,
    target_size = (512, 256),
    batch_size = 128,
    class_mode = 'binary')
# Out:
# Found 35047 images belonging to 2 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
    dir_path_val,
    target_size = (512, 256),
    batch_size = 128,
    class_mode = 'binary')
# Out:
# Found 8749 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    dir_path_test,
    target_size = (512, 256),
    batch_size = 128,
    class_mode = 'binary')
# Out:
# Found 10962 images belonging to 2 classes.

# %%
# Importação do modelo VGG-16 com seus pesos pré-treinados sem a última camada.
from keras.applications.vgg16 import VGG16

model_vgg16 = VGG16(weights = 'imagenet', input_shape = (512, 256, 3), include_top = False)

for layer in model_vgg16.layers:
    layer.trainable = False

# Inclusão de uma camada de Average Pooling, mais duas camadas densas (completamente conectadas) intercaladas por dropouts.
x = model_vgg16.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs = model_vgg16.input, outputs = predictions)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 512, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 512, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 256, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 256, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 256, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 128, 64, 128)      0
#
#  block3_conv1 (Conv2D)       (None, 128, 64, 256)      295168
#
#  block3_conv2 (Conv2D)       (None, 128, 64, 256)      590080
#
#  block3_conv3 (Conv2D)       (None, 128, 64, 256)      590080
#
#  block3_pool (MaxPooling2D)  (None, 64, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 64, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 64, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 64, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 32, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 32, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 32, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 32, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 16, 8, 512)        0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 14,788,673
# Trainable params: 73,985
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Configuramos aqui um monitoramente de métricas para que após algumas épocas sem melhoras
# no modelo possamos economizar poder computacional e salvar sempre o melhor na acurácia de validação.
early_stopper = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", mode = "min", patience = 30)
save_model = tf.keras.callbacks.ModelCheckpoint(filepath = '/content/drive/My Drive/inf0619_trabalho_final/producao/baseline_vgg16.h5'
                                                , monitor = "val_loss"
                                                , mode = "min"
                                                , save_best_only = True)

# Definimos aqui a função que chamará os modelos e irá realizar o procedimento de treinamento.
def trainModel(model, epochs, optimizer, class_weights, callbacks = []):
    batch_size = 128
    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
    return model.fit(train_generator
                     , validation_data=validation_generator
                     , epochs=epochs
                     , batch_size=batch_size
                     , callbacks=callbacks
                     , class_weight = class_weights)

adam =  Adam(learning_rate=0.00005)

model_history = trainModel(model = model, epochs = 60, optimizer = adam, class_weights = class_weights, callbacks = [early_stopper, save_model])
# Out:
# Epoch 1/60
# 274/274 [==============================] - 641s 2s/step - loss: 1.2030 - accuracy: 0.4721 - val_loss: 0.7107 - val_accuracy: 0.4789
# Epoch 2/60
# 274/274 [==============================] - 579s 2s/step - loss: 0.9042 - accuracy: 0.4888 - val_loss: 0.7378 - val_accuracy: 0.3773
# Epoch 3/60
# 274/274 [==============================] - 579s 2s/step - loss: 0.7991 - accuracy: 0.4733 - val_loss: 0.7183 - val_accuracy: 0.4100
# Epoch 4/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7695 - accuracy: 0.4892 - val_loss: 0.7391 - val_accuracy: 0.3228
# Epoch 5/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7567 - accuracy: 0.4835 - val_loss: 0.7310 - val_accuracy: 0.3290
# Epoch 6/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.7329 - accuracy: 0.4521 - val_loss: 0.6920 - val_accuracy: 0.4986
# Epoch 7/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7332 - accuracy: 0.4937 - val_loss: 0.7094 - val_accuracy: 0.4063
# Epoch 8/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7207 - accuracy: 0.4999 - val_loss: 0.6961 - val_accuracy: 0.4580
# Epoch 9/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7221 - accuracy: 0.4766 - val_loss: 0.7031 - val_accuracy: 0.4168
# Epoch 10/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7201 - accuracy: 0.4774 - val_loss: 0.6944 - val_accuracy: 0.4697
# Epoch 11/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.7118 - accuracy: 0.4977 - val_loss: 0.6841 - val_accuracy: 0.5107
# Epoch 12/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7119 - accuracy: 0.5118 - val_loss: 0.6942 - val_accuracy: 0.4812
# Epoch 13/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7062 - accuracy: 0.4857 - val_loss: 0.7093 - val_accuracy: 0.4413
# Epoch 14/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.7072 - accuracy: 0.5080 - val_loss: 0.6821 - val_accuracy: 0.5297
# Epoch 15/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.7040 - accuracy: 0.5213 - val_loss: 0.6755 - val_accuracy: 0.5420
# Epoch 16/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7030 - accuracy: 0.5159 - val_loss: 0.6817 - val_accuracy: 0.4971
# Epoch 17/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.7019 - accuracy: 0.4996 - val_loss: 0.6782 - val_accuracy: 0.5131
# Epoch 18/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.6946 - accuracy: 0.4962 - val_loss: 0.6711 - val_accuracy: 0.5587
# Epoch 19/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6932 - accuracy: 0.5456 - val_loss: 0.6885 - val_accuracy: 0.4911
# Epoch 20/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6997 - accuracy: 0.4770 - val_loss: 0.6897 - val_accuracy: 0.4881
# Epoch 21/60
# 274/274 [==============================] - 582s 2s/step - loss: 0.6983 - accuracy: 0.5014 - val_loss: 0.6693 - val_accuracy: 0.5523
# Epoch 22/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6921 - accuracy: 0.5107 - val_loss: 0.6773 - val_accuracy: 0.5375
# Epoch 23/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.6876 - accuracy: 0.5150 - val_loss: 0.6639 - val_accuracy: 0.5816
# Epoch 24/60
# 274/274 [==============================] - 582s 2s/step - loss: 0.6876 - accuracy: 0.5428 - val_loss: 0.6544 - val_accuracy: 0.6187
# Epoch 25/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.6876 - accuracy: 0.5343 - val_loss: 0.6651 - val_accuracy: 0.5738
# Epoch 26/60
# 274/274 [==============================] - 582s 2s/step - loss: 0.6883 - accuracy: 0.5347 - val_loss: 0.6484 - val_accuracy: 0.6168
# Epoch 27/60
# 274/274 [==============================] - 582s 2s/step - loss: 0.6801 - accuracy: 0.5428 - val_loss: 0.6400 - val_accuracy: 0.6437
# Epoch 28/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.6891 - accuracy: 0.5340 - val_loss: 0.6192 - val_accuracy: 0.6973
# Epoch 29/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6846 - accuracy: 0.5534 - val_loss: 0.6576 - val_accuracy: 0.5755
# Epoch 30/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6782 - accuracy: 0.5099 - val_loss: 0.6540 - val_accuracy: 0.6022
# Epoch 31/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6754 - accuracy: 0.5353 - val_loss: 0.6479 - val_accuracy: 0.6067
# Epoch 32/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6732 - accuracy: 0.5238 - val_loss: 0.6501 - val_accuracy: 0.5880
# Epoch 33/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6707 - accuracy: 0.5316 - val_loss: 0.6311 - val_accuracy: 0.6421
# Epoch 34/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6762 - accuracy: 0.5524 - val_loss: 0.6361 - val_accuracy: 0.6432
# Epoch 35/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6768 - accuracy: 0.5292 - val_loss: 0.6650 - val_accuracy: 0.5462
# Epoch 36/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6724 - accuracy: 0.5302 - val_loss: 0.6410 - val_accuracy: 0.6158
# Epoch 37/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6663 - accuracy: 0.5575 - val_loss: 0.6519 - val_accuracy: 0.6001
# Epoch 38/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6649 - accuracy: 0.5569 - val_loss: 0.6475 - val_accuracy: 0.6065
# Epoch 39/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6580 - accuracy: 0.5629 - val_loss: 0.6292 - val_accuracy: 0.6406
# Epoch 40/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6655 - accuracy: 0.5678 - val_loss: 0.6230 - val_accuracy: 0.6654
# Epoch 41/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6610 - accuracy: 0.5674 - val_loss: 0.6540 - val_accuracy: 0.5742
# Epoch 42/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6601 - accuracy: 0.5705 - val_loss: 0.6680 - val_accuracy: 0.5462
# Epoch 43/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6626 - accuracy: 0.5474 - val_loss: 0.6379 - val_accuracy: 0.6187
# Epoch 44/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6540 - accuracy: 0.5688 - val_loss: 0.6472 - val_accuracy: 0.5813
# Epoch 45/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6555 - accuracy: 0.5518 - val_loss: 0.6303 - val_accuracy: 0.6145
# Epoch 46/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6480 - accuracy: 0.5838 - val_loss: 0.6220 - val_accuracy: 0.6369
# Epoch 47/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6489 - accuracy: 0.5884 - val_loss: 0.6382 - val_accuracy: 0.6115
# Epoch 48/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6467 - accuracy: 0.5775 - val_loss: 0.6215 - val_accuracy: 0.6413
# Epoch 49/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6415 - accuracy: 0.5832 - val_loss: 0.6518 - val_accuracy: 0.5779
# Epoch 50/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6437 - accuracy: 0.5758 - val_loss: 0.6445 - val_accuracy: 0.5825
# Epoch 51/60
# 274/274 [==============================] - 582s 2s/step - loss: 0.6399 - accuracy: 0.5688 - val_loss: 0.6163 - val_accuracy: 0.6441
# Epoch 52/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6373 - accuracy: 0.5887 - val_loss: 0.6191 - val_accuracy: 0.6344
# Epoch 53/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6395 - accuracy: 0.5755 - val_loss: 0.6184 - val_accuracy: 0.6386
# Epoch 54/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.6371 - accuracy: 0.5870 - val_loss: 0.6027 - val_accuracy: 0.6603
# Epoch 55/60
# 274/274 [==============================] - 581s 2s/step - loss: 0.6307 - accuracy: 0.5915 - val_loss: 0.5626 - val_accuracy: 0.7372
# Epoch 56/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6253 - accuracy: 0.6167 - val_loss: 0.6029 - val_accuracy: 0.6595
# Epoch 57/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6299 - accuracy: 0.6028 - val_loss: 0.6285 - val_accuracy: 0.6129
# Epoch 58/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6246 - accuracy: 0.5869 - val_loss: 0.5976 - val_accuracy: 0.6675
# Epoch 59/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6273 - accuracy: 0.5983 - val_loss: 0.5751 - val_accuracy: 0.7045
# Epoch 60/60
# 274/274 [==============================] - 580s 2s/step - loss: 0.6198 - accuracy: 0.6090 - val_loss: 0.6053 - val_accuracy: 0.6448

# %%
# Criação dos vetores com as informações de acurácia e perdas dos conjuntos de treinamento e validação do modelo.
accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# Plot das curvas de acurácia e perdas do treinamento do modelo.
plt.figure(figsize = (15,10))

plt.subplot(2, 2, 1)
plt.plot(accuracy, label = "Training Accuracy")
plt.plot(val_accuracy, label = "Validation Accuracy")
plt.ylim(0.4, 1)
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.title("Training vs Validation Accuracy")
plt.xlabel('epoch')
plt.ylabel('accuracy')


plt.subplot(2, 2, 2)
plt.plot(loss, label = "Training Loss")
plt.plot(val_loss, label = "Validation Loss")
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.title("Training vs Validation Loss")
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
# carregamento dos pesos da rede após o treinamento para realização da predição do conjunto de testes.
model_vgg16 = load_model('/content/drive/My Drive/inf0619_trabalho_final/producao/baseline_vgg16.h5')

pred_vgg16 = model_vgg16.predict(test_generator)

y_pred_vgg16 = []
for prob in pred_vgg16:
    if prob >= 0.5:
        y_pred_vgg16.append(1)
    else:
        y_pred_vgg16.append(0)

y_true = test_generator.classes

# Plot da matriz de confusão para a predição de cancer no nível imagem.
cm = confusion_matrix(y_true, y_pred_vgg16)
cm_pct = confusion_matrix(y_true, y_pred_vgg16, normalize = "true")

class_names = ['Negativo', 'Positivo']

ax = sns.heatmap(cm_pct*100, annot = True, fmt = '.2f', cmap = "Blues", annot_kws = {"size": 16},\
           xticklabels = class_names, yticklabels = class_names)

# Impressão na matriz confusão dos resultados em número de imagens e o respectivo percentual dentro da classe.
i=0
for t in ax.texts:
  t.set_text(str(cm.flatten()[i])+ "\n("+ t.get_text() + "%)")
  i = i+1

ax.set_xlabel("Predição")
ax.set_ylabel("Real")
# Out:
# 86/86 [==============================] - 162s 2s/step
# Text(50.722222222222214, 0.5, 'Real')

# %%
# Sequência de joins necessários para agregar o resultado das predições do nível imagem para paciente + lateralidade.
df_test_generator = pd.DataFrame(test_generator.filenames, columns=["img_path"])
df_test_generator["img_path"] = df_test_generator["img_path"].str.split("/", expand=True)[1]
df_test_generator = pd.merge(df_test_generator, pd.merge(df_test[["patient_id", "laterality"]], df_test["img_path"].str.split("/", expand=True)[[7]].rename(columns={7:"img_path"}), how='inner',left_index=True, right_index=True), how='inner', on='img_path')
df_test_generator = pd.merge(df_test_generator, df_test.groupby(["patient_id", "laterality"]).agg(cancer_true=("cancer","max")).reset_index(), how='inner', on=["patient_id", "laterality"])
df_test_generator = pd.merge(df_test_generator, pd.DataFrame(y_pred_vgg16, columns=["cancer_pred"]), how='inner', left_index=True, right_index=True)
df_test_generator = df_test_generator.groupby(["patient_id","laterality"]).agg(cancer_true=("cancer_true", "max"), cancer_pred=("cancer_pred", "max")).reset_index()
df_test_generator["patient_lat_id"] = df_test_generator["patient_id"].astype(str) + "_" + df_test_generator["laterality"]

# Plot da matriz de confusão para a predição de cancer no nível paciente + lateralidade.
cm = confusion_matrix(df_test_generator["cancer_true"].values , df_test_generator["cancer_pred"].values)
cm_pct = confusion_matrix(df_test_generator["cancer_true"].values, df_test_generator["cancer_pred"].values, normalize = "true")

class_names = ['Negativo', 'Positivo']

ax = sns.heatmap(cm_pct*100, annot = True, fmt = '.2f', cmap = "Blues", annot_kws = {"size": 16},\
           xticklabels = class_names, yticklabels = class_names)

# Impressão na matriz confusão dos resultados em número de paciente + lateralidade e o respectivo percentual dentro da classe.
i=0
for t in ax.texts:
  t.set_text(str(cm.flatten()[i])+ "\n("+ t.get_text() + "%)")
  i = i+1

ax.set_xlabel("Predição")
ax.set_ylabel("Real")
# Out:
# Text(50.722222222222214, 0.5, 'Real')
