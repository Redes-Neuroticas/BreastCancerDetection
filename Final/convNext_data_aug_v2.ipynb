# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import import_ipynb
import seaborn as sns
import shutil
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ConvNeXtTiny

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from utils import *
# Out:
# 2023-07-03 09:47:51.922026: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-03 09:47:51.948474: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-03 09:47:52.356629: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# importing Jupyter notebook from utils.ipynb

# %%
# clean_all_datasets()

# Criando os diretórios:
# create_dataset_dirs()
    
# Criando os subdiretórios
# build_train_dataset_from_ori_imgs(df_train_split)
    
# build_val_dataset_from_ori_imgs(df_val_split)

# build_test_dataset_from_ori_imgs(df_test)

# %%
# Criando geradores de imagem para o tensorflow:

train_datagen = ImageDataGenerator(validation_split=0.2)
test_datagen = ImageDataGenerator()

# %%
target_size = (512, 512)

train_generator = train_datagen.flow_from_directory(
    train_dir_path,
    # classes = class_names,
    target_size = target_size,
    batch_size = 48,
    class_mode = 'binary',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
        train_dir_path,
        # classes = class_names,
        target_size = target_size,
        batch_size = 48,
        class_mode = 'binary',
        subset='validation')

test_generator = test_datagen.flow_from_directory(
        test_dir_path,
        # classes = class_names,
        target_size = target_size,
        batch_size = 48,
        class_mode = 'binary')
# Out:
# Found 11410 images belonging to 2 classes.
# Found 2852 images belonging to 2 classes.
# Found 0 images belonging to 2 classes.

# %%
def plot_images(dataset):
    fig, axes = plt.subplots(4, 4, figsize=(12, 12))
    images, labels = next(dataset)
    axes = axes.ravel()
    for i in range(9):
      image = images[i]
      # print_img_props(image)
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(image, cmap='gray')
      plt.axis("off")
    
plot_images(train_generator)
# Out:
# /tmp/ipykernel_11676/3629864925.py:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(3, 3, i + 1)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model

model_convNext = ConvNeXtTiny(weights = 'imagenet', input_shape = (target_size[0], target_size[1], 3), include_top = False)

for layer in model_convNext.layers:
    layer.trainable = False
    
# build the entire model
x = model_convNext.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x) 
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu')(x) 
x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu')(x) 
x = layers.Dropout(0.5)(x)
predictions = layers.Dense(1, activation='sigmoid')(x)
model = Model(inputs = model_convNext.input, outputs = predictions)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  convnext_tiny_prestem_normaliz  (None, 512, 512, 3)  0          ['input_2[0][0]']
#  ation (Normalization)
#
#  convnext_tiny_stem (Sequential  (None, 128, 128, 96  4896       ['convnext_tiny_prestem_normaliza
#  )                              )                                tion[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 96  4800       ['convnext_tiny_stem[0][0]']
#  depthwise_conv (Conv2D)        )
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 96  192        ['convnext_tiny_stage_0_block_0_d
#  layernorm (LayerNormalization)  )                               epthwise_conv[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 38  37248      ['convnext_tiny_stage_0_block_0_l
#  pointwise_conv_1 (Dense)       4)                               ayernorm[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 38  0          ['convnext_tiny_stage_0_block_0_p
#  gelu (Activation)              4)                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 96  36960      ['convnext_tiny_stage_0_block_0_g
#  pointwise_conv_2 (Dense)       )                                elu[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 96  96         ['convnext_tiny_stage_0_block_0_p
#  layer_scale (LayerScale)       )                                ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 128, 128, 96  0          ['convnext_tiny_stage_0_block_0_l
#  identity (Activation)          )                                ayer_scale[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 128, 128, 96  0          ['convnext_tiny_stem[0][0]',
#  ambda)                         )                                 'convnext_tiny_stage_0_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 96  4800       ['tf.__operators__.add_18[0][0]']
#  depthwise_conv (Conv2D)        )
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 96  192        ['convnext_tiny_stage_0_block_1_d
#  layernorm (LayerNormalization)  )                               epthwise_conv[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 38  37248      ['convnext_tiny_stage_0_block_1_l
#  pointwise_conv_1 (Dense)       4)                               ayernorm[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 38  0          ['convnext_tiny_stage_0_block_1_p
#  gelu (Activation)              4)                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 96  36960      ['convnext_tiny_stage_0_block_1_g
#  pointwise_conv_2 (Dense)       )                                elu[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 96  96         ['convnext_tiny_stage_0_block_1_p
#  layer_scale (LayerScale)       )                                ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 128, 128, 96  0          ['convnext_tiny_stage_0_block_1_l
#  identity (Activation)          )                                ayer_scale[0][0]']
#
#  tf.__operators__.add_19 (TFOpL  (None, 128, 128, 96  0          ['tf.__operators__.add_18[0][0]',
#  ambda)                         )                                 'convnext_tiny_stage_0_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 96  4800       ['tf.__operators__.add_19[0][0]']
#  depthwise_conv (Conv2D)        )
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 96  192        ['convnext_tiny_stage_0_block_2_d
#  layernorm (LayerNormalization)  )                               epthwise_conv[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 38  37248      ['convnext_tiny_stage_0_block_2_l
#  pointwise_conv_1 (Dense)       4)                               ayernorm[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 38  0          ['convnext_tiny_stage_0_block_2_p
#  gelu (Activation)              4)                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 96  36960      ['convnext_tiny_stage_0_block_2_g
#  pointwise_conv_2 (Dense)       )                                elu[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 96  96         ['convnext_tiny_stage_0_block_2_p
#  layer_scale (LayerScale)       )                                ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 128, 128, 96  0          ['convnext_tiny_stage_0_block_2_l
#  identity (Activation)          )                                ayer_scale[0][0]']
#
#  tf.__operators__.add_20 (TFOpL  (None, 128, 128, 96  0          ['tf.__operators__.add_19[0][0]',
#  ambda)                         )                                 'convnext_tiny_stage_0_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_downsampling_blo  (None, 64, 64, 192)  74112      ['tf.__operators__.add_20[0][0]']
#  ck_0 (Sequential)
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 192)  9600       ['convnext_tiny_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_0[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 192)  384        ['convnext_tiny_stage_1_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 768)  148224     ['convnext_tiny_stage_1_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 768)  0          ['convnext_tiny_stage_1_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 192)  147648     ['convnext_tiny_stage_1_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 192)  192        ['convnext_tiny_stage_1_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 64, 64, 192)  0          ['convnext_tiny_stage_1_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_21 (TFOpL  (None, 64, 64, 192)  0          ['convnext_tiny_downsampling_bloc
#  ambda)                                                          k_0[0][0]',
#                                                                   'convnext_tiny_stage_1_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 192)  9600       ['tf.__operators__.add_21[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 192)  384        ['convnext_tiny_stage_1_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 768)  148224     ['convnext_tiny_stage_1_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 768)  0          ['convnext_tiny_stage_1_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 192)  147648     ['convnext_tiny_stage_1_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 192)  192        ['convnext_tiny_stage_1_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 64, 64, 192)  0          ['convnext_tiny_stage_1_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 64, 64, 192)  0          ['tf.__operators__.add_21[0][0]',
#  ambda)                                                           'convnext_tiny_stage_1_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 192)  9600       ['tf.__operators__.add_22[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 192)  384        ['convnext_tiny_stage_1_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 768)  148224     ['convnext_tiny_stage_1_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 768)  0          ['convnext_tiny_stage_1_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 192)  147648     ['convnext_tiny_stage_1_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 192)  192        ['convnext_tiny_stage_1_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 64, 64, 192)  0          ['convnext_tiny_stage_1_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 64, 64, 192)  0          ['tf.__operators__.add_22[0][0]',
#  ambda)                                                           'convnext_tiny_stage_1_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_downsampling_blo  (None, 32, 32, 384)  295680     ['tf.__operators__.add_23[0][0]']
#  ck_1 (Sequential)
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 384)  19200      ['convnext_tiny_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_1[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 384)  768        ['convnext_tiny_stage_2_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 1536  591360     ['convnext_tiny_stage_2_block_0_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 1536  0          ['convnext_tiny_stage_2_block_0_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 384)  590208     ['convnext_tiny_stage_2_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 384)  384        ['convnext_tiny_stage_2_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 32, 32, 384)  0          ['convnext_tiny_stage_2_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add
p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 16, 16, 768)  2360064    ['convnext_tiny_stage_3_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 16, 16, 768)  768        ['convnext_tiny_stage_3_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 16, 16, 768)  0          ['convnext_tiny_stage_3_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_33 (TFOpL  (None, 16, 16, 768)  0          ['convnext_tiny_downsampling_bloc
#  ambda)                                                          k_2[0][0]',
#                                                                   'convnext_tiny_stage_3_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 768)  38400      ['tf.__operators__.add_33[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 768)  1536       ['convnext_tiny_stage_3_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 3072  2362368    ['convnext_tiny_stage_3_block_1_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 3072  0          ['convnext_tiny_stage_3_block_1_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 768)  2360064    ['convnext_tiny_stage_3_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 768)  768        ['convnext_tiny_stage_3_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 16, 16, 768)  0          ['convnext_tiny_stage_3_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None, 16, 16, 768)  0          ['tf.__operators__.add_33[0][0]',
#  ambda)                                                           'convnext_tiny_stage_3_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 768)  38400      ['tf.__operators__.add_34[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 768)  1536       ['convnext_tiny_stage_3_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 3072  2362368    ['convnext_tiny_stage_3_block_2_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 3072  0          ['convnext_tiny_stage_3_block_2_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 768)  2360064    ['convnext_tiny_stage_3_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 768)  768        ['convnext_tiny_stage_3_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 16, 16, 768)  0          ['convnext_tiny_stage_3_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_35 (TFOpL  (None, 16, 16, 768)  0          ['tf.__operators__.add_34[0][0]',
#  ambda)                                                           'convnext_tiny_stage_3_block_2_i
#                                                                  dentity[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 16, 16, 768)  1536       ['tf.__operators__.add_35[0][0]']
#  rmalization)
#
#  global_average_pooling2d_1 (Gl  (None, 768)         0           ['layer_normalization_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 256)          196864      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 128)          32896       ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 64)           8256        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 64)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 1)            65          ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 28,058,209
# Trainable params: 238,081
# Non-trainable params: 27,820,128
# __________________________________________________________________________________________________

# %%
# %load_ext tensorboard
from datetime import datetime

logs_dir = '/home/kasco/MDC/FinalProject/BreastCancerDetection/logs'

logdir = os.path.join(logs_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from keras.optimizers import SGD, Adam

early_stopper = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", mode = "min", patience = 20)
save_model = tf.keras.callbacks.ModelCheckpoint(filepath = 'augmentation_convnext_v2.h5', monitor = "val_loss", mode = "min", save_best_only = True)

# define training function
def trainModel(model, epochs, optimizer, callbacks = []):
    batch_size = 48
    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
    return model.fit(train_generator,
                     validation_data=validation_generator,
                      epochs=epochs,
                      steps_per_epoch = train_generator.samples // batch_size,
                      validation_steps = validation_generator.samples // batch_size,
                      batch_size=batch_size,
                      callbacks=callbacks)

sgd = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
adam =  Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model_history = trainModel(model = model, epochs = 250, optimizer = adam, callbacks = [early_stopper, save_model, tensorboard_callback])
# Out:
# Epoch 1/250
# 2023-07-01 10:35:35.223487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
#
# Epoch 21/250
# 237/237 [==============================] - 352s 1s/step - loss: 0.6895 - accuracy: 0.5312 - val_loss: 0.6907 - val_accuracy: 0.5300
# Epoch 22/250
# 237/237 [==============================] - 354s 1s/step - loss: 0.6917 - accuracy: 0.5267 - val_loss: 0.6908 - val_accuracy: 0.5311
# Epoch 23/250
# 237/237 [==============================] - 353s 1s/step - loss: 0.6884 - accuracy: 0.5374 - val_loss: 0.6905 - val_accuracy: 0.5311
# Epoch 24/250
# 237/237 [==============================] - 350s 1s/step - loss: 0.6889 - accuracy: 0.5348 - val_loss: 0.6906 - val_accuracy: 0.5381
# Epoch 25/250
# 237/237 [==============================] - 353s 1s/step - loss: 0.6885 - accuracy: 0.5330 - val_loss: 0.6907 - val_accuracy: 0.5374

# %%
accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# %%
plt.figure(figsize = (15,10))

plt.subplot(2, 2, 1)
plt.plot(accuracy, label = "Training Accuracy")
plt.plot(val_accuracy, label = "Validation Accuracy")
plt.ylim(0.4, 1)
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.title("Training vs Validation Accuracy")
plt.xlabel('epoch')
plt.ylabel('accuracy')


plt.subplot(2, 2, 2)
plt.plot(loss, label = "Training Loss")
plt.plot(val_loss, label = "Validation Loss")
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.title("Training vs Validation Loss")
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
model_convNext =  load_model('augmentation_convnext_v2.h5')

pred_resnet50 = model_convNext.predict(test_generator)

y_pred_resnet50 = []
for prob in pred_resnet50:
    if prob >= 0.5:
        y_pred_resnet50.append(1)
    else:
        y_pred_resnet50.append(0)
        
y_true = test_generator.classes

cm = confusion_matrix(y_true, y_pred_resnet50)

class_names = ['Positivo', 'Negativo']

ax = sns.heatmap(cm, annot = True, fmt = '.0f', cmap = "Blues", annot_kws = {"size": 16},\
           xticklabels = class_names, yticklabels = class_names)

ax.set_xlabel("Predição")
ax.set_ylabel("Real")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model_convNext =  load_model('augmentation_convnext_v2.h5')
#       3 pred_resnet50 = model_convNext.predict(test_generator)
#       5 y_pred_resnet50 = []
#
# File ~/anaconda3/envs/mdc-tf-gpu/lib/python3.9/site-packages/keras/saving/saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File ~/anaconda3/envs/mdc-tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/mdc-tf-gpu/lib/python3.9/site-packages/keras/saving/legacy/serialization.py:368, in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     364 cls = object_registration.get_registered_object(
#     365     class_name, custom_objects, module_objects
#     366 )
#     367 if cls is None:
# --> 368     raise ValueError(
#     369         f"Unknown {printable_module_name}: '{class_name}'. "
#     370         "Please ensure you are using a `keras.utils.custom_object_scope` "
#     371         "and that this object is included in the scope. See "
#     372         "https://www.tensorflow.org/guide/keras/save_and_serialize"
#     373         "#registering_the_custom_object for details."
#     374     )
#     376 cls_config = config["config"]
#     377 # Check if `cls_config` is a list. If it is a list, return the class and the
#     378 # associated class configs for recursively deserialization. This case will
#     379 # happen on the old version of sequential model (e.g. `keras_version` ==
#     380 # "2.0.6"), which is serialized in a different structure, for example
#     381 # "{'class_name': 'Sequential',
#     382 #   'config': [{'class_name': 'Embedding', 'config': ...}, {}, ...]}".
#
# ValueError: Unknown layer: 'LayerScale'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.
