png
#   inflating: __MACOSX/baseline/val/wout_cancer/._1085527870.png
#   inflating: baseline/val/wout_cancer/2022571586.png
#   inflating: __MACOSX/baseline/val/wout_cancer/._2022571586.png
#   inflating: baseline/val/wout_cancer/799595851.png
#   inflating: __MACOSX/baseline/val/wout_cancer/._799595851.png
#   inflating: baseline/val/wout_cancer/2071468623.png
#   inflating: __MACOSX/baseline/val/wout_cancer/._2071468623.png
#   inflating: baseline/val/wout_cancer/1272043923.png
#   inflating: __MACOSX/baseline/val/wout_cancer/._1272043923.png
#   inflating: baseline/val/wout_cancer/391410545.png
#   inflating: __MACOSX/baseline/val/wout_cancer/._391410545.png
#   inflating: baseline/val/wout_cancer/1906075102.png
#   inflating: __MACOSX/baseline/val/wout_cancer/._1906075102.png

# %%
! mv baseline/train/wout_cancer baseline/train/0
! mv baseline/train/with_cancer baseline/train/1
! mv baseline/val/wout_cancer baseline/val/0
! mv baseline/val/with_cancer baseline/val/1
! mv baseline/test/wout_cancer baseline/test/0
! mv baseline/test/with_cancer baseline/test/1

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5471602887793754588
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14328594432
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3015593477508414215
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Dataset attributes
#
# - **site_id** - ID code for the source hospital.
# - **patient_id** - ID code for the patient.
# - **image_id** - ID code for the image.
# - **laterality** - Whether the image is of the left (L) or right (R) breast.
# - **view** - The orientation of the image. The default for a screening exam is to capture two views per breast.
# - **age** - The patient's age in years.
# - **cancer** - Whether or not the breast was positive for malignant cancer. The target value. Only provided for train.
# - **biopsy** - Whether or not a follow-up biopsy was performed on the breast. Only provided for train.
# - **invasive** - If the breast is positive for cancer, whether or not the cancer proved to be invasive. Only provided for train.
# - **BIRADS** - 0 if the breast required follow-up, 1 if the breast was rated as negative for cancer, and 2 if the breast was rated as normal. Only provided for train.
# - **implant** - Whether or not the patient had breast implants. Site 1 only provides breast implant information at the patient level, not at the breast level.
# - **density** - A rating for how dense the breast tissue is, with A being the least dense and D being the most dense. Extremely dense tissue can make diagnosis more difficult. Only provided for train.
# - **machine_id** - An ID code for the imaging device.
# - **difficult_negative_case** - True if the case was unusually difficult. Only provided for train.

# %% [markdown]
# ## BASE DE TREINAMENTO

# %%
df_train = pd.read_csv('/content/drive/My Drive/inf0619_trabalho_final/train.csv', sep=",")
df_train
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10006   462822612          L   CC  61.0       0       0
# 1            2       10006  1459541791          L  MLO  61.0       0       0
# 2            2       10006  1864590858          R  MLO  61.0       0       0
# 3            2       10006  1874946579          R   CC  61.0       0       0
# 4            2       10011   220375232          L   CC  55.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 43739        1        9973  1729524723          R  MLO  43.0       0       0
# 43740        1        9989    63473691          L  MLO  60.0       0       0
# 43741        1        9989  1078943060          L   CC  60.0       0       0
# 43742        1        9989   398038886          R  MLO  60.0       0       0
# 43743        1        9989   439796429          R   CC  60.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 0             0     NaN        0     NaN          29                    False
# 1             0     NaN        0     NaN          29                    False
# 2             0     NaN        0     NaN          29                    False
# 3             0     NaN        0     NaN          29                    False
# 4             0     0.0        0     NaN          21                     True
# ...         ...     ...      ...     ...         ...                      ...
# 43739         0     1.0        0       C          49                    False
# 43740         0     NaN        0       C         216                    False
# 43741         0     NaN        0       C         216                    False
# 43742         0     0.0        0       C         216                     True
# 43743         0     0.0        0       C         216                     True
#
# [43744 rows x 14 columns]

# %%
# Número total de imagens:
print("Número total de imagens: ", df_train["image_id"].count())

# Vamos analisar os números com relação aos hospitais (site_id):
print("Número de diferentes hospitais: ", df_train["site_id"].nunique(), ", cujos códigos são: ", df_train["site_id"].unique())
print("Distribuição de imagens por hospital: ", df_train.groupby("site_id").agg(qtde=("image_id","count")).reset_index())

# Número de pacientes distintos (patient_id):
print("Número de pacientes distintos:" , df_train["patient_id"].nunique())

# Distribuição de imagens com relação a lateralidade (laterality):
print("Número de imagens de seios esquerdos (L) e direitos (R):" , df_train.groupby("laterality").agg(qtde=("image_id","count")).reset_index())

# Distribuição de imagens com relação a sua orientação (view):
print("Número de imagens em cada orientação:" , df_train.groupby("view").agg(qtde=("image_id","count")).reset_index().sort_values(by="qtde", ascending=False))

# Número de imagens com implante (implant):
print("Número de imagens com e sem implante:" , df_train.groupby("implant").agg(qtde=("image_id","count")).reset_index())

# Número de imagens com e sem Câncer (cancer):
print("Número de imagens com e sem Câncer:" , df_train.groupby("cancer").agg(qtde=("image_id","count")).reset_index())

# Número de imagens positivas para câncer classificadas como invasivas (invasive):
print("Número de imagens positivas para câncer classificadas como invasivas:" , df_train[df_train["cancer"]==1].groupby("invasive").agg(qtde=("image_id","count")).reset_index())

# Número de imagens classificadas como extraordinariamente dificeis (difficult_negative_case):
print("Número de imagens classificadas como extraordinariamente dificeis:" , df_train.groupby("difficult_negative_case").agg(qtde=("image_id","count")).reset_index())

# Distribuição de imagens de acordo com a densidade do tecido mamário (density):
print("Distribuição de imagens de acordo com a densidade do tecido mamário: ", df_train.groupby("density").agg(qtde=("image_id","count")).reset_index())

# Relação entre diagnósticos de cancer com biópsias (cancer, biopsy):
print("Relação entre diagnósticos de cancer com biópsias: ", df_train.groupby(["cancer", "biopsy"]).agg(qtde=("image_id","count")).reset_index())
# Out:
# Número total de imagens:  43744
# Número de diferentes hospitais:  2 , cujos códigos são:  [2 1]
# Distribuição de imagens por hospital:     site_id   qtde
# 0        1  23709
# 1        2  20035
# Número de pacientes distintos: 9530
# Número de imagens de seios esquerdos (L) e direitos (R):   laterality   qtde
# 0          L  21806
# 1          R  21938
# Número de imagens em cada orientação:   view   qtde
# 5  MLO  22302
# 1   CC  21413
# 0   AT     16
# 4   ML      7
# 2   LM      5
# 3  LMO      1
# Número de imagens com e sem implante:    implant   qtde
# 0        0  42587
# 1        1   1157
# Número de imagens com e sem Câncer:    cancer   qtde
# 0       0  42778
# 1       1    966
# Número de imagens positivas para câncer classificadas como invasivas:    invasive  qtde
# 0         0   273
# 1         1   693
# Número de imagens classificadas como extraordinariamente dificeis:    difficult_negative_case   qtde
# 0                    False  37537
# 1                     True   6207
# Distribuição de imagens de acordo com a densidade do tecido mamário:    density   qtde
# 0       A   2501
# 1       B  10182
# 2       C   9757
# 3       D   1234
# Relação entre diagnósticos de cancer com biópsias:     cancer  biopsy   qtde
# 0       0       0  41302
# 1       0       1   1476
# 2       1       1    966

# %% [markdown]
# * Pelos números acima, vemos que existe um desbalanceamento enorme para a classe negativa de câncer (97,8%) contra a positiva (2,2%);
# * Existem pouquíssimas imagens com implantes (2,65%);
# * Mais de 99% das imagens estão orientadas nas posições CC (craniocaudal) e MLO (mediolateral obliquo);
# * Há um balanço no número de imagens com relação ao hospital de origem e lado dos seios;
# * Identificamos 6207 imagens que estão classificadas como extraordinariamente dificeis;
# * Das 966 imagens positivas para câncer, cerca de 40% não são invasivas;
# * A distribuição de imagens de acordo com a densidade do tecido mamário tem uma concentração para os níveis B e C (densidades médias);
# * No total tivemos 2.442 imagens com biópsias. Todos os casos de cancer positivo tiveram biópsias. Não houve casos de cancer positivo sem biópsia.

# %%
# Análise dos campos buscando valores faltantes:
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43744 entries, 0 to 43743
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   site_id                  43744 non-null  int64
#  1   patient_id               43744 non-null  int64
#  2   image_id                 43744 non-null  int64
#  3   laterality               43744 non-null  object
#  4   view                     43744 non-null  object
#  5   age                      43720 non-null  float64
#  6   cancer                   43744 non-null  int64
#  7   biopsy                   43744 non-null  int64
#  8   invasive                 43744 non-null  int64
#  9   BIRADS                   20959 non-null  float64
#  10  implant                  43744 non-null  int64
#  11  density                  23674 non-null  object
#  12  machine_id               43744 non-null  int64
#  13  difficult_negative_case  43744 non-null  bool
# dtypes: bool(1), float64(2), int64(8), object(3)
# memory usage: 4.4+ MB

# %% [markdown]
# Identificamos 3 campos com valores faltantes:
# * **age**     - 24 registros nulos. **Sugestão**: Substituir os valores faltantes pela média;
# * **BIRADS**  - 22.785 registros nulos (52%). **Sugestão**: O campo está disponível apenas no conjunto de treinamento;
# * **density** - 20.070 registros nulos (46%). **Sugestão**: O campo está disponível apenas no conjunto de treinamento;

# %% [markdown]
# ## BASE DE TESTE

# %%
df_test = pd.read_csv('/content/drive/My Drive/inf0619_trabalho_final/test.csv', sep=",")
df_test
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10048   964141995          L  MLO  62.0       0       0
# 1            2       10048  1234933874          L   CC  62.0       0       0
# 2            2       10048  1577142909          R  MLO  62.0       0       0
# 3            2       10048  1842203124          R   CC  62.0       0       0
# 4            2       10050   588678397          L  MLO  67.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 10957        2        9965  1990076391          R  MLO  67.0       0       0
# 10958        2        9968   766198919          L   CC  76.0       0       0
# 10959        2        9968  2098937312          L  MLO  76.0       0       0
# 10960        2        9968   294168046          R  MLO  76.0       0       0
# 10961        2        9968   568005453          R   CC  76.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 0             0     NaN        0     NaN          29                    False
# 1             0     NaN        0     NaN          29                    False
# 2             0     NaN        0     NaN          29                    False
# 3             0     NaN        0     NaN          29                    False
# 4             0     NaN        0     NaN          29                    False
# ...         ...     ...      ...     ...         ...                      ...
# 10957         0     NaN        0     NaN          21                    False
# 10958         0     NaN        0     NaN          48                    False
# 10959         0     NaN        0     NaN          48                    False
# 10960         0     NaN        0     NaN          48                    False
# 10961         0     NaN        0     NaN          48                    False
#
# [10962 rows x 14 columns]

# %%
# Número total de imagens:
print("Número total de imagens: ", df_test["image_id"].count())

# Vamos analisar os números com relação aos hospitais (site_id):
print("Número de diferentes hospitais: ", df_test["site_id"].nunique(), ", cujos códigos são: ", df_test["site_id"].unique())
print("Distribuição de imagens por hospital: ", df_test.groupby("site_id").agg(qtde=("image_id","count")).reset_index())

# Número de pacientes distintos (patient_id):
print("Número de pacientes distintos:" , df_test["patient_id"].nunique())

# Distribuição de imagens com relação a lateralidade (laterality):
print("Número de imagens de seios esquerdos (L) e direitos (R):" , df_test.groupby("laterality").agg(qtde=("image_id","count")).reset_index())

# Distribuição de imagens com relação a sua orientação (view):
print("Número de imagens em cada orientação:" , df_test.groupby("view").agg(qtde=("image_id","count")).reset_index().sort_values(by="qtde", ascending=False))

# Número de imagens com implante (implant):
print("Número de imagens com e sem implante:" , df_test.groupby("implant").agg(qtde=("image_id","count")).reset_index())
# Out:
# Número total de imagens:  10962
# Número de diferentes hospitais:  2 , cujos códigos são:  [2 1]
# Distribuição de imagens por hospital:     site_id  qtde
# 0        1  5810
# 1        2  5152
# Número de pacientes distintos: 2383
# Número de imagens de seios esquerdos (L) e direitos (R):   laterality  qtde
# 0          L  5461
# 1          R  5501
# Número de imagens em cada orientação:   view  qtde
# 4  MLO  5601
# 1   CC  5352
# 2   LM     5
# 0   AT     3
# 3   ML     1
# Número de imagens com e sem implante:    implant   qtde
# 0        0  10642
# 1        1    320

# %% [markdown]
# Inicialmente vou considerar a solução mais simple de todas. Iremos identificar o balanceamento de cada classe e dizer ao modelo para dar mais peso a classe minoritária.

# %%
df_train["img_path"] =  "/content/drive/My Drive/inf0619_trabalho_final/images_256_512/" + df_train["patient_id"].astype(str) + "/" + df_train["image_id"].astype(str) + ".png"
df_train
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10006   462822612          L   CC  61.0       0       0
# 1            2       10006  1459541791          L  MLO  61.0       0       0
# 2            2       10006  1864590858          R  MLO  61.0       0       0
# 3            2       10006  1874946579          R   CC  61.0       0       0
# 4            2       10011   220375232          L   CC  55.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 43739        1        9973  1729524723          R  MLO  43.0       0       0
# 43740        1        9989    63473691          L  MLO  60.0       0       0
# 43741        1        9989  1078943060          L   CC  60.0       0       0
# 43742        1        9989   398038886          R  MLO  60.0       0       0
# 43743        1        9989   439796429          R   CC  60.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 0             0     NaN        0     NaN          29                    False
# 1             0     NaN        0     NaN          29                    False
# 2             0     NaN        0     NaN          29                    False
# 3             0     NaN        0     NaN          29                    False
# 4             0     0.0        0     NaN          21                     True
# ...         ...     ...      ...     ...         ...                      ...
# 43739         0     1.0        0       C          49                    False
# 43740         0     NaN        0       C         216                    False
# 43741         0     NaN        0       C         216                    False
# 43742         0     0.0        0       C         216                     True
# 43743         0     0.0        0       C         216                     True
#
#                                                 img_path
# 0      /content/drive/My Drive/inf0619_trabalho_final...
# 1      /content/drive/My Drive/inf0619_trabalho_final...
# 2      /content/drive/My Drive/inf0619_trabalho_final...
# 3      /content/drive/My Drive/inf0619_trabalho_final...
# 4      /content/drive/My Drive/inf0619_trabalho_final...
# ...                                                  ...
# 43739  /content/drive/My Drive/inf0619_trabalho_final...
# 43740  /content/drive/My Drive/inf0619_trabalho_final...
# 43741  /content/drive/My Drive/inf0619_trabalho_final...
# 43742  /content/drive/My Drive/inf0619_trabalho_final...
# 43743  /content/drive/My Drive/inf0619_trabalho_final...
#
# [43744 rows x 15 columns]

# %%
# Testando o caminho de uma imagem
img = cv2.imread(df_train.loc[0, 'img_path'])
plt.imshow(img, cmap = 'gray')

# %%
# Vamos separar os dados em treinamento e validação na proporção 80/20:
df_train_split, df_val_split = train_test_split(df_train, test_size = 0.2, random_state = 123456, stratify = df_train[['cancer']])

print("Número de imagens no conjunto de treinamento: ", df_train_split.shape[0])
print("Distribuição de cancer conjunto de treinamento: ", df_train_split.groupby("cancer").agg(qtde=("site_id","count")).reset_index())
print("Número de imagens no conjunto de validação: ", df_val_split.shape[0])
print("Distribuição de cancer no conjunto de validação: ", df_val_split.groupby("cancer").agg(qtde=("site_id","count")).reset_index())
# Out:
# Número de imagens no conjunto de treinamento:  34995
# Distribuição de cancer conjunto de treinamento:     cancer   qtde
# 0       0  34222
# 1       1    773
# Número de imagens no conjunto de validação:  8749
# Distribuição de cancer no conjunto de validação:     cancer  qtde
# 0       0  8556
# 1       1   193

# %% [markdown]
# ## Após separar os grupos de treinamento e validação, ler o parquet e continuar desse ponto.

# %%
df_train_split = pd.read_parquet("/content/drive/My Drive/inf0619_trabalho_final/df_train_split.parquet")
df_val_split = pd.read_parquet("/content/drive/My Drive/inf0619_trabalho_final/df_val_split.parquet")
df_train_split
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 32231        2       53681   645459855          R  MLO  72.0       0       0
# 5756         1       17691   204137417          L  MLO  54.0       0       0
# 22346        2       39923   939662454          R  MLO  67.0       0       0
# 26661        2       45967   577166135          L  MLO  60.0       0       0
# 2693         1       13556  1513389174          R   CC  64.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 10397        1       24032   292181380          R   CC  74.0       0       0
# 43138        2        9114  1516672792          R  MLO  62.0       0       0
# 23187        1       41047  1845566551          L  MLO  59.0       0       0
# 25449        1       44250  1403117425          R  MLO  76.0       0       0
# 12092        1       26273   970576175          R   CC  64.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 32231         0     NaN        0    None          21                    False
# 5756          0     NaN        0       A          49                    False
# 22346         0     NaN        0    None          48                    False
# 26661         0     NaN        0    None          48                    False
# 2693          0     1.0        0       A          49                    False
# ...         ...     ...      ...     ...         ...                      ...
# 10397         0     1.0        0       B          49                    False
# 43138         0     NaN        0    None          29                    False
# 23187         0     NaN        0       C          49                    False
# 25449         0     0.0        0       C          93                     True
# 12092         0     0.0        0       C          49                     True
#
#                                                 img_path
# 32231  /content/drive/My Drive/inf0619_trabalho_final...
# 5756   /content/drive/My Drive/inf0619_trabalho_final...
# 22346  /content/drive/My Drive/inf0619_trabalho_final...
# 26661  /content/drive/My Drive/inf0619_trabalho_final...
# 2693   /content/drive/My Drive/inf0619_trabalho_final...
# ...                                                  ...
# 10397  /content/drive/My Drive/inf0619_trabalho_final...
# 43138  /content/drive/My Drive/inf0619_trabalho_final...
# 23187  /content/drive/My Drive/inf0619_trabalho_final...
# 25449  /content/drive/My Drive/inf0619_trabalho_final...
# 12092  /content/drive/My Drive/inf0619_trabalho_final...
#
# [34995 rows x 15 columns]

# %%
df_test = pd.read_csv('/content/drive/My Drive/inf0619_trabalho_final/test.csv', sep=",")
df_test["img_path"] =  "/content/drive/My Drive/inf0619_trabalho_final/images_256_512/" + df_test["patient_id"].astype(str) + "/" + df_test["image_id"].astype(str) + ".png"
df_test
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10048   964141995          L  MLO  62.0       0       0
# 1            2       10048  1234933874          L   CC  62.0       0       0
# 2            2       10048  1577142909          R  MLO  62.0       0       0
# 3            2       10048  1842203124          R   CC  62.0       0       0
# 4            2       10050   588678397          L  MLO  67.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 10957        2        9965  1990076391          R  MLO  67.0       0       0
# 10958        2        9968   766198919          L   CC  76.0       0       0
# 10959        2        9968  2098937312          L  MLO  76.0       0       0
# 10960        2        9968   294168046          R  MLO  76.0       0       0
# 10961        2        9968   568005453          R   CC  76.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 0             0     NaN        0     NaN          29                    False
# 1             0     NaN        0     NaN          29                    False
# 2             0     NaN        0     NaN          29                    False
# 3             0     NaN        0     NaN          29                    False
# 4             0     NaN        0     NaN          29                    False
# ...         ...     ...      ...     ...         ...                      ...
# 10957         0     NaN        0     NaN          21                    False
# 10958         0     NaN        0     NaN          48                    False
# 10959         0     NaN        0     NaN          48                    False
# 10960         0     NaN        0     NaN          48                    False
# 10961         0     NaN        0     NaN          48                    False
#
#                                                 img_path
# 0      /content/drive/My Drive/inf0619_trabalho_final...
# 1      /content/drive/My Drive/inf0619_trabalho_final...
# 2      /content/drive/My Drive/inf0619_trabalho_final...
# 3      /content/drive/My Drive/inf0619_trabalho_final...
# 4      /content/drive/My Drive/inf0619_trabalho_final...
# ...                                                  ...
# 10957  /content/drive/My Drive/inf0619_trabalho_final...
# 10958  /content/drive/My Drive/inf0619_trabalho_final...
# 10959  /content/drive/My Drive/inf0619_trabalho_final...
# 10960  /content/drive/My Drive/inf0619_trabalho_final...
# 10961  /content/drive/My Drive/inf0619_trabalho_final...
#
# [10962 rows x 15 columns]

# %%
# Vamos calcular a distribuição das classes usando a biblioteca scikit-learn:
class_weights = class_weight.compute_class_weight(class_weight = 'balanced'
                                                  , classes = df_train_split["cancer"].unique()
                                                  , y = df_train_split["cancer"])
class_weights
# Out:
# array([ 0.5112939 , 22.63583441])

# %%
# Transformando em um dicionário:
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 0.5112939045058734, 1: 22.635834411384216}

# %%
# Iremos agora criar 4 diretórios (2 de teste e 2 de validação, um de positivos e outro de negativos para cancer)
# Demora demais no Drive. Fiz na mão.

dir_path_train = "/content/baseline/train"
dir_path_val = "/content/baseline/val"
dir_path_test = "/content/baseline/test"

# # Criando os diretórios:
# if os.path.exists(dir_path_train):
#     shutil.rmtree(dir_path_train)
# else:
#     os.makedirs(dir_path_train)

# if os.path.exists(dir_path_val):
#     shutil.rmtree(dir_path_val)
# else:
#     os.makedirs(dir_path_val)


# # Criando os subdiretórios
# os.makedirs(dir_path_train+"/with_cancer")
# for path in df_train_split[df_train_split["cancer"]==1]['img_path']:
#     shutil.copy2(path, dir_path_train+"/with_cancer")

# os.makedirs(dir_path_train+"/wout_cancer")
# for path in df_train_split[df_train_split["cancer"]==0]['img_path']:
#     shutil.copy2(path, dir_path_train+"/wout_cancer")

# os.makedirs(dir_path_val+"/with_cancer")
# for path in df_val_split[df_val_split["cancer"]==1]['img_path']:
#     shutil.copy2(path, dir_path_val+"/with_cancer")

# os.makedirs(dir_path_val+"/wout_cancer")
# for path in df_val_split[df_val_split["cancer"]==0]['img_path']:
#     shutil.copy2(path, dir_path_val+"/wout_cancer")

# %%
# Criando geradores de imagem para o tensorflow:
train_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input)

# %%
train_generator = train_datagen.flow_from_directory(
    dir_path_train,
    target_size = (512, 256),
    batch_size = 256,
    class_mode = 'binary')
# Out:
# Found 35047 images belonging to 2 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
    dir_path_val,
    target_size = (512, 256),
    batch_size = 256,
    class_mode = 'binary')
# Out:
# Found 8749 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    dir_path_test,
    target_size = (512, 256),
    batch_size = 256,
    class_mode = 'binary')
# Out:
# Found 10962 images belonging to 2 classes.

# %%
model_enetB5 = tf.keras.applications.EfficientNetB5(weights = 'imagenet', input_shape = (512, 256, 3), include_top = False)

for layer in model_enetB5.layers:
    layer.trainable = False

# build the entire model
x = model_enetB5.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs = model_enetB5.input, outputs = predictions)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 256, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 512, 256, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 512, 256, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 512, 256, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 513, 257, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 256, 128, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 128, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 128, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 256, 128, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 256, 128, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 256, 128, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 256, 128, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 256, 128, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 128, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 256, 128, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 256, 128, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 256, 128, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 256, 128, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 128, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 128, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 256, 128, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 256, 128, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 256, 128, 24  216        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 256, 128, 24  96         ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 256, 128, 24  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 24)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 256, 128, 24  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 256, 128, 24  576         ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 256, 128, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 256, 128, 24  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 256, 128, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 256, 128, 14  3456        ['block1c_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 256, 128, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 256, 128, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 257, 129, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 128, 64, 144  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             )
#
#  block2a_bn (BatchNormalization  (None, 128, 64, 144  576        ['block2a_dwconv[0][0]']
#  )                              )
#
#  block2a_activation (Activation  (None, 128, 64, 144  0          ['block2a_bn[0][0]']
#  )                              )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 128, 64, 144  0           ['block2a_activation[0][0]',
#                                 )                                 'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 128, 64, 40)  5760        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 128, 64, 40)  160        ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 128, 64, 240  9600        ['block2a_project_bn[0][0]']
#                                 )
#
#  block2b_expand_bn (BatchNormal  (None, 128, 64, 240  960        ['block2b_expand_conv[0][0]']
#  ization)                       )
#
#  block2b_expand_activation (Act  (None, 128, 64, 240  0          ['block2b_expand_bn[0][0]']
#  ivation)                       )
#
#  block2b_dwconv (DepthwiseConv2  (None, 128, 64, 240  2160       ['block2b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block2b_bn (BatchNormalization  (None, 128, 64, 240  960        ['block2b_dwconv[0][0]']
#  )                              )
#
#  block2b_activation (Activation  (None, 128, 64, 240  0          ['block2b_bn[0][0]']
#  )                              )
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 128, 64, 240  0           ['block2b_activation[0][0]',
#                                 )                                 'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 128, 64, 40)  9600        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 128, 64, 40)  160        ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 128, 64, 40)  0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 128, 64, 40)  0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 64, 240  9600        ['block2b_add[0][0]']
#                                 )
#
#  block2c_expand_bn (BatchNormal  (None, 128, 64, 240  960        ['block2c_expand_conv[0][0]']
#  ization)                       )
#
#  block2c_expand_activation (Act  (None, 128, 64, 240  0          ['block2c_expand_bn[0][0]']
#  ivation)                       )
#
#  block2c_dwconv (DepthwiseConv2  (None, 128, 64, 240  2160       ['block2c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block2c_bn (BatchNormalization  (None, 128, 64, 240  960        ['block2c_dwconv[0][0]']
#  )                              )
#
#  block2c_activation (Activation  (None, 128, 64, 240  0          ['block2c_bn[0][0]']
#  )                              )
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 128, 64, 240  0           ['block2c_activation[0][0]',
#                                 )                                 'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 128, 64, 40)  9600        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 128, 64, 40)  160        ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 128, 64, 40)  0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 128, 64, 40)  0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 64, 240  9600        ['block2c_add[0][0]']
#                                 )
#
#  block2d_expand_bn (BatchNormal  (None, 128, 64, 240  960        ['block2d_expand_conv[0][0]']
#  ization)                       )
#
#  block2d_expand_activation (Act  (None, 128, 64, 240  0          ['block2d_expand_bn[0][0]']
#  ivation)                       )
#
#  block2d_dwconv (DepthwiseConv2  (None, 128, 64, 240  2160       ['block2d_expand_activation[0][0]
#  D)                             )                                ']
#
#  block2d_bn (BatchNormalization  (None, 128, 64, 240  960        ['block2d_dwconv[0][0]']
#  )                              )
#
#  block2d_activation (Activation  (None, 128, 64, 240  0          ['block2d_bn[0][0]']
#  )                              )
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 128, 64, 240  0           ['block2d_activation[0][0]',
#                                 )                                 'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 128, 64, 40)  9600        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 128, 64, 40)  160        ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 128, 64, 40)  0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 128, 64, 40)  0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 128, 64, 240  9600        ['block2d_add[0][0]']
#                                 )
#
#  block2e_expand_bn (BatchNormal  (None, 128, 64, 240  960        ['block2e_expand_conv[0][0]']
#  ization)                       )
#
#  block2e_expand_activation (Act  (None, 128, 64, 240  0          ['block2e_expand_bn[0][0]']
#  ivation)                       )
#
#  block2e_dwconv (DepthwiseConv2  (None, 128, 64, 240  2160       ['block2e_expand_activation[0][0]
#  D)                             )                                ']
#
#  block2e_bn (BatchNormalization  (None, 128, 64, 240  960        ['block2e_dwconv[0][0]']
#  )                              )
#
#  block2e_activation (Activation  (None, 128, 64, 240  0          ['block2e_bn[0][0]']
#  )                              )
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 128, 64, 240  0           ['block2e_activation[0][0]',
#                                 )                                 'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 128, 64, 40)  9600        ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 128, 64, 40)  160        ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 128, 64, 40)  0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 128, 64, 40)  0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 128, 64, 240  9600        ['block2e_add[0][0]']
#                                 )
#
#  block3a_expand_bn (BatchNormal  (None, 128, 64, 240  960        ['block3a_expand_conv[0][0]']
#  ization)                       )
#
#  block3a_expand_activation (Act  (None, 128, 64, 240  0          ['block3a_expand_bn[0][0]']
#  ivation)                       )
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 131, 67, 240  0          ['block3a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 64, 32, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 64, 32, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 64, 32, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 64, 32, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 64, 32, 64)   15360       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 64, 32, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 32, 384)  24576       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 32, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 32, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 64, 32, 384)  9600       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 64, 32, 384)  1536       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 64, 32, 384)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 384)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 64, 32, 384)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 64, 32, 64)   24576       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 64, 32, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 64, 32, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 32, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 32, 384)  24576       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 32, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 32, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 64, 32, 384)  9600       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 64, 32, 384)  1536       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 64, 32, 384)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 384)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 64, 32, 384)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 64, 32, 64)   24576       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 64, 32, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 64, 32, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 32, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 32, 384)  24576       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 32, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 32, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 64, 32, 384)  9600       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 64, 32, 384)  1536       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 64, 32, 384)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 384)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 64, 32, 384)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 64, 32, 64)   24576       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 64, 32, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 64, 32, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 64, 32, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 64, 32, 384)  24576       ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 64, 32, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 64, 32, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_dwconv (DepthwiseConv2  (None, 64, 32, 384)  9600       ['block3e_expand_activation[0][0]
#  D)                                                              ']
#
#  block3e_bn (BatchNormalization  (None, 64, 32, 384)  1536       ['block3e_dwconv[0][0]']
#  )
#
# ...
#
#  block6i_activation (Activation  (None, 16, 8, 1824)  0          ['block6i_bn[0][0]']
#  )
#
#  block6i_se_squeeze (GlobalAver  (None, 1824)        0           ['block6i_activation[0][0]']
#  agePooling2D)
#
#  block6i_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block6i_se_squeeze[0][0]']
#
#  block6i_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multiply)   (None, 16, 8, 1824)  0           ['block6i_activation[0][0]',
#                                                                   'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv2D)  (None, 16, 8, 304)   554496      ['block6i_se_excite[0][0]']
#
#  block6i_project_bn (BatchNorma  (None, 16, 8, 304)  1216        ['block6i_project_conv[0][0]']
#  lization)
#
#  block6i_drop (Dropout)         (None, 16, 8, 304)   0           ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)              (None, 16, 8, 304)   0           ['block6i_drop[0][0]',
#                                                                   'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 8, 1824)  554496      ['block6i_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 16, 8, 1824)  7296       ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 16, 8, 1824)  0          ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 8, 1824)  16416      ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 16, 8, 1824)  7296       ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 16, 8, 1824)  0          ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1824)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 8, 1824)  0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 8, 512)   933888      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 8, 512)  2048        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 8, 3072)  1572864     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 16, 8, 3072)  12288      ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 16, 8, 3072)  0          ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 8, 3072)  27648      ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 16, 8, 3072)  12288      ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 16, 8, 3072)  0          ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 8, 3072)  0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 8, 512)   1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 8, 512)  2048        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 8, 512)   0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 8, 512)   0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 8, 3072)  1572864     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 16, 8, 3072)  12288      ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 16, 8, 3072)  0          ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv (DepthwiseConv2  (None, 16, 8, 3072)  27648      ['block7c_expand_activation[0][0]
#  D)                                                              ']
#
#  block7c_bn (BatchNormalization  (None, 16, 8, 3072)  12288      ['block7c_dwconv[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 16, 8, 3072)  0          ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 8, 3072)  0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 8, 512)   1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 8, 512)  2048        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 16, 8, 512)   0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 8, 512)   0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 8, 2048)  1048576     ['block7c_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 16, 8, 2048)  8192        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 16, 8, 2048)  0           ['top_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          262272      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            65          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 28,784,120
# Trainable params: 270,593
# Non-trainable params: 28,513,527
# __________________________________________________________________________________________________

# %%
early_stopper = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", mode = "min", patience = 10)
save_model = tf.keras.callbacks.ModelCheckpoint(filepath = '/content/drive/My Drive/inf0619_trabalho_final/producao/baseline_enetB5.h5'
                                                , monitor = "val_loss"
                                                , mode = "min"
                                                , save_best_only = True)

# define training function
def trainModel(model, epochs, optimizer, class_weights, callbacks = []):
    batch_size = 256
    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
    return model.fit(train_generator
                     , validation_data=validation_generator
                     , epochs=epochs
                     , batch_size=batch_size
                     , callbacks=callbacks
                     , class_weight = class_weights)

adam =  Adam(learning_rate=0.00005)

model_history = trainModel(model = model, epochs = 60, optimizer = adam, class_weights = class_weights, callbacks = [early_stopper, save_model])
# Out:
# Epoch 1/60
# 137/137 [==============================] - 184s 1s/step - loss: 0.7341 - accuracy: 0.5287 - val_loss: 0.7032 - val_accuracy: 0.4303
# Epoch 2/60
# 137/137 [==============================] - 163s 1s/step - loss: 0.7157 - accuracy: 0.4550 - val_loss: 0.7005 - val_accuracy: 0.4615
# Epoch 3/60
# 137/137 [==============================] - 164s 1s/step - loss: 0.7104 - accuracy: 0.4644 - val_loss: 0.7034 - val_accuracy: 0.4778
# Epoch 4/60
# 137/137 [==============================] - 164s 1s/step - loss: 0.7094 - accuracy: 0.4721 - val_loss: 0.6830 - val_accuracy: 0.5974
# Epoch 5/60
# 137/137 [==============================] - 163s 1s/step - loss: 0.7041 - accuracy: 0.4888 - val_loss: 0.6957 - val_accuracy: 0.5193
# Epoch 6/60
# 137/137 [==============================] - 165s 1s/step - loss: 0.7063 - accuracy: 0.5074 - val_loss: 0.6932 - val_accuracy: 0.5324
# Epoch 7/60
# 137/137 [==============================] - 166s 1s/step - loss: 0.7005 - accuracy: 0.5193 - val_loss: 0.6790 - val_accuracy: 0.5905
# Epoch 8/60
# 137/137 [==============================] - 165s 1s/step - loss: 0.6992 - accuracy: 0.5682 - val_loss: 0.6781 - val_accuracy: 0.5949
# Epoch 9/60
# 137/137 [==============================] - 165s 1s/step - loss: 0.7004 - accuracy: 0.5110 - val_loss: 0.6579 - val_accuracy: 0.6587
# Epoch 10/60
# 137/137 [==============================] - 164s 1s/step - loss: 0.6936 - accuracy: 0.5548 - val_loss: 0.6868 - val_accuracy: 0.5567
# Epoch 11/60
# 137/137 [==============================] - 164s 1s/step - loss: 0.6848 - accuracy: 0.5575 - val_loss: 0.6640 - val_accuracy: 0.6182
# Epoch 12/60
# 137/137 [==============================] - 167s 1s/step - loss: 0.6880 - accuracy: 0.5617 - val_loss: 0.6480 - val_accuracy: 0.6554
# Epoch 13/60
# 137/137 [==============================] - 163s 1s/step - loss: 0.6892 - accuracy: 0.5770 - val_loss: 0.6941 - val_accuracy: 0.5444
# Epoch 14/60
# 137/137 [==============================] - 167s 1s/step - loss: 0.6847 - accuracy: 0.5535 - val_loss: 0.6892 - val_accuracy: 0.5494
# Epoch 15/60
# 137/137 [==============================] - 162s 1s/step - loss: 0.6814 - accuracy: 0.5648 - val_loss: 0.6519 - val_accuracy: 0.6496
# Epoch 16/60
# 137/137 [==============================] - 164s 1s/step - loss: 0.
uracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure(figsize = (15,10))

plt.subplot(2, 2, 1)
plt.plot(accuracy, label = "Training Accuracy")
plt.plot(val_accuracy, label = "Validation Accuracy")
plt.ylim(0.4, 1)
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.title("Training vs Validation Accuracy")
plt.xlabel('epoch')
plt.ylabel('accuracy')


plt.subplot(2, 2, 2)
plt.plot(loss, label = "Training Loss")
plt.plot(val_loss, label = "Validation Loss")
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.title("Training vs Validation Loss")
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
model_enetB5 = load_model('/content/drive/My Drive/inf0619_trabalho_final/producao/baseline_enetB5.h5')

pred_enetB5 = model_enetB5.predict(test_generator)

y_pred_enetB5 = []
for prob in pred_enetB5:
    if prob >= 0.5:
        y_pred_enetB5.append(1)
    else:
        y_pred_enetB5.append(0)

y_true = test_generator.classes

cm = confusion_matrix(y_true , y_pred_enetB5)
cm_pct = confusion_matrix(y_true, y_pred_enetB5, normalize = "true")

class_names = ['Negativo', 'Positivo']

ax = sns.heatmap(cm_pct*100, annot = True, fmt = '.2f', cmap = "Blues", annot_kws = {"size": 16},\
           xticklabels = class_names, yticklabels = class_names)

i=0
for t in ax.texts:
  t.set_text(str(cm.flatten()[i])+ "\n("+ t.get_text() + "%)")
  i = i+1

ax.set_xlabel("Predição")
ax.set_ylabel("Real")
# Out:
# 43/43 [==============================] - 46s 990ms/step
# Text(50.722222222222214, 0.5, 'Real')

# %%
df_test_generator = pd.DataFrame(test_generator.filenames, columns=["img_path"])
df_test_generator["img_path"] = df_test_generator["img_path"].str.split("/", expand=True)[1]
df_test_generator = pd.merge(df_test_generator, pd.merge(df_test[["patient_id", "laterality"]], df_test["img_path"].str.split("/", expand=True)[[7]].rename(columns={7:"img_path"}), how='inner',left_index=True, right_index=True), how='inner', on='img_path')
df_test_generator = pd.merge(df_test_generator, df_test.groupby(["patient_id", "laterality"]).agg(cancer_true=("cancer","max")).reset_index(), how='inner', on=["patient_id", "laterality"])
df_test_generator = pd.merge(df_test_generator, pd.DataFrame(y_pred_enetB5, columns=["cancer_pred"]), how='inner', left_index=True, right_index=True)
df_test_generator = df_test_generator.groupby(["patient_id","laterality"]).agg(cancer_true=("cancer_true", "max"), cancer_pred=("cancer_pred", "max")).reset_index()
df_test_generator["patient_lat_id"] = df_test_generator["patient_id"].astype(str) + "_" + df_test_generator["laterality"]

cm = confusion_matrix(df_test_generator["cancer_true"].values , df_test_generator["cancer_pred"].values)
cm_pct = confusion_matrix(df_test_generator["cancer_true"].values, df_test_generator["cancer_pred"].values, normalize = "true")

class_names = ['Negativo', 'Positivo']

ax = sns.heatmap(cm_pct*100, annot = True, fmt = '.2f', cmap = "Blues", annot_kws = {"size": 16},\
           xticklabels = class_names, yticklabels = class_names)

i=0
for t in ax.texts:
  t.set_text(str(cm.flatten()[i])+ "\n("+ t.get_text() + "%)")
  i = i+1

ax.set_xlabel("Predição")
ax.set_ylabel("Real")
# Out:
# Text(50.722222222222214, 0.5, 'Real')
